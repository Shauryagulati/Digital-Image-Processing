# %% [markdown]
# <a href="https://colab.research.google.com/github/Shauryagulati/Digital-Image-Processing/blob/main/DIP10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow

# %% [markdown]
# ##Erosion

# %%
import cv2 as cv
import numpy as np
img = cv.imread('image1.jpg')
kernel = np.ones((5,5),np.uint8)
erosion = cv.erode(img,kernel,iterations = 1)
from google.colab.patches import cv2_imshow
print('Original Image')
cv2_imshow(img)
print('Eroded Image')
cv2_imshow(erosion)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# Original Image
# <PIL.Image.Image image mode=RGB size=500x250 at 0x7F7ECAD640B8>
# Eroded Image
# <PIL.Image.Image image mode=RGB size=500x250 at 0x7F7ECAD650B8>

# %% [markdown]
# ##Dilation

# %%
import cv2 as cv
import numpy as np
img = cv.imread('image1.jpg')
kernel = np.ones((5,5),np.uint8)
dilation = cv.dilate(img,kernel,iterations = 1)
from google.colab.patches import cv2_imshow
print('Original Image')
cv2_imshow(img)
print('Dilated Image')
cv2_imshow(dilation)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# Original Image
# <PIL.Image.Image image mode=RGB size=500x250 at 0x7F7ECAD0C748>
# Dilated Image
# <PIL.Image.Image image mode=RGB size=500x250 at 0x7F7ECAD0C710>

# %% [markdown]
# ##Opening

# %%
import cv2 as cv
import numpy as np
img = cv.imread('image1.jpg')
kernel = np.ones((5,5),np.uint8)
opening = cv.morphologyEx(img, cv.MORPH_OPEN, kernel)
from google.colab.patches import cv2_imshow
print('Original Image')
cv2_imshow(img)
print('Opening Image')
cv2_imshow(opening)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# Original Image
# <PIL.Image.Image image mode=RGB size=500x250 at 0x7F7ECAD13CC0>
# Opening Image
# <PIL.Image.Image image mode=RGB size=500x250 at 0x7F7ECAD13DD8>

# %% [markdown]
# ##Closing

# %%
import cv2 as cv
import numpy as np
img = cv.imread('image1.jpg')
kernel = np.ones((5,5),np.uint8)
closing = cv.morphologyEx(img, cv.MORPH_CLOSE, kernel)
from google.colab.patches import cv2_imshow
print('Original Image')
cv2_imshow(img)
print('Closing Image')
cv2_imshow(closing)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# Original Image
# <PIL.Image.Image image mode=RGB size=500x250 at 0x7F7ECAD18898>
# Closing Image
# <PIL.Image.Image image mode=RGB size=500x250 at 0x7F7ECAD18828>

# %% [markdown]
# ##Gradient

# %%
import cv2 as cv
import numpy as np
img = cv.imread('image1.jpg')
kernel = np.ones((5,5),np.uint8)
gradient = cv.morphologyEx(img, cv.MORPH_GRADIENT, kernel)
from google.colab.patches import cv2_imshow
print('Original Image')
cv2_imshow(img)
print('Morphological Gradient Image')
cv2_imshow(gradient)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# Original Image
# <PIL.Image.Image image mode=RGB size=500x250 at 0x7F7ECAD18978>
# Morphological Gradient Image
# <PIL.Image.Image image mode=RGB size=500x250 at 0x7F7ECAD18710>

# %% [markdown]
# ##Top Hat

# %%
import cv2 as cv
import numpy as np
img = cv.imread('image1.jpg')
kernel = np.ones((5,5),np.uint8)
tophat = cv.morphologyEx(img, cv.MORPH_TOPHAT, kernel)
from google.colab.patches import cv2_imshow
print('Original Image')
cv2_imshow(img)
print('Top Hat Image')
cv2_imshow(tophat)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# Original Image
# <PIL.Image.Image image mode=RGB size=500x250 at 0x7F7ECAD18C18>
# Top Hat Image
# <PIL.Image.Image image mode=RGB size=500x250 at 0x7F7ECAD18BE0>

# %% [markdown]
# ##Black Hat

# %%
import cv2 as cv
import numpy as np
img = cv.imread('image1.jpg')
kernel = np.ones((5,5),np.uint8)
blackhat = cv.morphologyEx(img, cv.MORPH_BLACKHAT, kernel)
from google.colab.patches import cv2_imshow
print('Original Image')
cv2_imshow(img)
print('Black Hat Image')
cv2_imshow(blackhat)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# Original Image
# <PIL.Image.Image image mode=RGB size=500x250 at 0x7F7EC2FBA860>
# Black Hat Image
# <PIL.Image.Image image mode=RGB size=500x250 at 0x7F7EC2FBA828>

# %% [markdown]
# ##Alternate Methods

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('grayscale.png')

_, mask = cv2.threshold(img, 220, 255, cv2.THRESH_BINARY_INV)
titles= ['image','mask']
images=[img,mask]
for i in range(2):
  plt.subplot(1, 2, i+1), plt.imshow(images[i], 'gray')
  plt.title(titles[i])
  plt.xticks([]),plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('grayscale.png')

_, mask = cv2.threshold(img, 220, 255, cv2.THRESH_BINARY_INV)
kernal = np.ones((5,5), np.uint8)
dilation = cv2.dilate(mask, kernal, iterations=2)

titles= ['image','mask','dilation']
images=[img,mask,dilation]
for i in range(3):
  plt.subplot(1, 3, i+1), plt.imshow(images[i], 'gray')
  plt.title(titles[i])
  plt.xticks([]),plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('grayscale.png')

_, mask = cv2.threshold(img, 220, 255, cv2.THRESH_BINARY_INV)
kernal = np.ones((2,2), np.uint8)
erosion = cv2.erode(mask, kernal)

titles= ['image','mask','erosion']
images=[img,mask,erosion]
for i in range(3):
  plt.subplot(1,3, i+1), plt.imshow(images[i], 'gray')
  plt.title(titles[i])
  plt.xticks([]),plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('grayscale.png')

_, mask = cv2.threshold(img, 220, 255, cv2.THRESH_BINARY_INV)
kernal = np.ones((2,2), np.uint8)
opening = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernal)

titles= ['image','mask','opening']
images=[img,mask,opening]
for i in range(3):
  plt.subplot(1,3, i+1), plt.imshow(images[i], 'gray')
  plt.title(titles[i])
  plt.xticks([]),plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('grayscale.png')

_, mask = cv2.threshold(img, 220, 255, cv2.THRESH_BINARY_INV)
kernal = np.ones((2,2), np.uint8)
closing = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernal)

titles= ['image','mask','closing']
images=[img,mask,closing]
for i in range(3):
  plt.subplot(1,3, i+1), plt.imshow(images[i], 'gray')
  plt.title(titles[i])
  plt.xticks([]),plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('grayscale.png')

_, mask = cv2.threshold(img, 220, 255, cv2.THRESH_BINARY_INV)
kernal = np.ones((2,2), np.uint8)
mg = cv2.morphologyEx(mask, cv2.MORPH_GRADIENT, kernal)

titles= ['image','mask','morphological']
images=[img,mask,mg]
for i in range(3):
  plt.subplot(1,3, i+1), plt.imshow(images[i], 'gray')
  plt.title(titles[i])
  plt.xticks([]),plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('grayscale.png')

# applying mask, img, value of threshnold, max alue of threshold, type of threshold
_, mask = cv2.threshold(img, 220, 255, cv2.THRESH_BINARY_INV)
kernal = np.ones((5,5), np.uint8)

dilation = cv2.dilate(mask, kernal, iterations=2)
erosion = cv2.erode(mask, kernal, iterations=1)
opening = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernal)
closing = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernal)
mg = cv2.morphologyEx(mask, cv2.MORPH_GRADIENT, kernal)
th = cv2.morphologyEx(mask, cv2.MORPH_TOPHAT, kernal)
titles = ['image', 'mask', 'dilation', 'erosion', 'opening', 'closing', 'mg', 'th']
images = [img, mask, dilation, erosion, opening, closing, mg, th]
for i in range(8):
  plt.subplot(2, 4, i+1), plt.imshow(images[i], 'gray')
  plt.title(titles[i])
  plt.xticks([]),plt.yticks([])
